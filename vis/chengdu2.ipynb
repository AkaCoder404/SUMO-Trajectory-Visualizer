# %% [markdown]
# # Chengdu Dataset
#
# This aims at performing EDA on the Chengdu dataset.
#
# ![chengdu](./chengdu_osm_all.png)

# %%
import folium
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import osmnx as ox
import os
import glob
from tqdm import tqdm

# %%
# Using OSMnx to download the road network of Chengdu
north = 30.73
south = 30.59
west = 104.17
east = 103.98
chengdu_road = ox.graph_from_bbox(north, south, east, west, network_type='drive')
print(chengdu_road)
ox.plot_graph(chengdu_road, figsize=(15,15), show=False, close=False)
# Out:
# /var/folders/xs/8ytvq8397bz3p0mp2cdjyd_40000gn/T/ipykernel_40174/1969657738.py:6: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   chengdu_road = ox.graph_from_bbox(north, south, east, west, network_type='drive')
# /var/folders/xs/8ytvq8397bz3p0mp2cdjyd_40000gn/T/ipykernel_40174/1969657738.py:6: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   chengdu_road = ox.graph_from_bbox(north, south, east, west, network_type='drive')
# MultiDiGraph with 11669 nodes and 26483 edges
# (<Figure size 1500x1500 with 1 Axes>, <Axes: >)

# %% [markdown]
# We can compare it to the map taking directly from OSM.
#
# <div style="text-align: center;">
#     <table>
#         <tr>
#             <td><img src="./chengdu_osm_core.png" alt="Image 1" width="300" height="300"></td>
#             <td><img src="./chengdu_osmnx_core.png" alt="Image 1" width="300" height="300"></td>
#         </tr>
#     </table>
# </div>

# %% [markdown]
# ## Data
# Let's take a look at the data more specifically
